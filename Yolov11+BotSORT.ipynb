# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya948351/MargVedhaMain/blob/main/Yolov11%2BBotSORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1️⃣ Allow DetectionModel for PyTorch
from torch.serialization import add_safe_globals
from ultralytics.nn.tasks import DetectionModel
add_safe_globals([DetectionModel])

# 2️⃣ Setup sys.argv so argparse works
import sys
sys.argv = ["Maincode.py", "--config", "cameras_config.json", "--out", "outputs"]

# 3️⃣ Import and run main
from Maincode import main  # assuming your file is Main_code.py
main("cameras_config.json", "outputs")
# Out:
# [cam1_north] Starting. source=data/cam1.mp4 weights=weights/yolov11m.pt
#
# video 1/1 (frame 1/601) /content/data/cam1.mp4: 384x640 3 cars, 98.3ms
# video 1/1 (frame 2/601) /content/data/cam1.mp4: 384x640 3 cars, 24.3ms
# video 1/1 (frame 3/601) /content/data/cam1.mp4: 384x640 3 cars, 24.2ms
# video 1/1 (frame 4/601) /content/data/cam1.mp4: 384x640 3 cars, 24.2ms
# video 1/1 (frame 5/601) /content/data/cam1.mp4: 384x640 4 cars, 24.3ms
# video 1/1 (frame 6/601) /content/data/cam1.mp4: 384x640 4 cars, 24.2ms
# video 1/1 (frame 7/601) /content/data/cam1.mp4: 384x640 5 cars, 24.2ms
# video 1/1 (frame 8/601) /content/data/cam1.mp4: 384x640 5 cars, 22.3ms
# video 1/1 (frame 9/601) /content/data/cam1.mp4: 384x640 5 cars, 22.3ms
# video 1/1 (frame 10/601) /content/data/cam1.mp4: 384x640 5 cars, 22.3ms
# video 1/1 (frame 11/601) /content/data/cam1.mp4: 384x640 5 cars, 22.2ms
# video 1/1 (frame 12/601) /content/data/cam1.mp4: 384x640 5 cars, 21.9ms
# ...

# %%
# !pip install -r requirements.txt
